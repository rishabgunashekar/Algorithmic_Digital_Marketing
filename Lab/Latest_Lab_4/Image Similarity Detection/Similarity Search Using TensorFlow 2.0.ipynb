# %%
#################################################
# This script reads image feature vectors from a folder
# and saves the image similarity scores in json file
# by Erdem Isbilen - December/2019
#################################################

#################################################
# Imports and function definitions
#################################################

# Numpy for loading image feature vectors from file
import numpy as np

# Time for measuring the process time
import time

# Glob for reading file names in a folder
import glob
import os.path

# json for storing data in json file
import json

# Annoy and Scipy for similarity calculation
from annoy import AnnoyIndex
from scipy import spatial
#################################################

#################################################
# This function reads from 'image_data.json' file
# Looks for a specific 'filename' value
# Returns the product id when product image names are matched 
# So it is used to find product id based on the product image name
#################################################
def match_id(filename):
  with open('E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/image_data.json') as json_file:
    
    for file in json_file:
        seen = json.loads(file)

        for line in seen:
          
          if filename==line['imageName']:
            print(line)
            return line['productId']
            break
#################################################

#################################################
# This function; 
# Reads all image feature vectores stored in /feature-vectors/*.npz
# Adds them all in Annoy Index
# Builds ANNOY index
# Calculates the nearest neighbors and image similarity metrics
# Stores image similarity scores with productID in a json file
#################################################
def cluster():

  start_time = time.time()
  
  print("---------------------------------")
  print ("Step.1 - ANNOY index generation - Started at %s" %time.ctime())
  print("---------------------------------")

  # Defining data structures as empty dict
  file_index_to_file_name = {}
  file_index_to_file_vector = {}
  file_index_to_product_id = {}

  # Configuring annoy parameters
  dims = 1792
  n_nearest_neighbors = 20
  trees = 10000

  # Reads all file names which stores feature vectors 
  allfiles = glob.glob('E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test/*.npz')

  t = AnnoyIndex(dims, metric='angular')

  for file_index, i in enumerate(allfiles):
    
    # Reads feature vectors and assigns them into the file_vector 
    file_vector = np.loadtxt(i)

    # Assigns file_name, feature_vectors and corresponding product_id
    file_name = os.path.basename(i).split('.')[0]
    file_index_to_file_name[file_index] = file_name
    file_index_to_file_vector[file_index] = file_vector
    file_index_to_product_id[file_index] = match_id(file_name)

    # Adds image feature vectors into annoy index   
    t.add_item(file_index, file_vector)

    print("---------------------------------")
    print("Annoy index     : %s" %file_index)
    print("Image file name : %s" %file_name)
    print("Product id      : %s" %file_index_to_product_id[file_index])
    print("--- %.2f minutes passed ---------" % ((time.time() - start_time)/60))


  # Builds annoy index
  t.build(trees)

  print ("Step.1 - ANNOY index generation - Finished")
  print ("Step.2 - Similarity score calculation - Started ") 
  
  named_nearest_neighbors = []

  # Loops through all indexed items
  for i in file_index_to_file_name.keys():

    # Assigns master file_name, image feature vectors and product id values
    master_file_name = file_index_to_file_name[i]
    master_vector = file_index_to_file_vector[i]
    master_product_id = file_index_to_product_id[i]

    # Calculates the nearest neighbors of the master item
    nearest_neighbors = t.get_nns_by_item(i, n_nearest_neighbors)

    # Loops through the nearest neighbors of the master item
    for j in nearest_neighbors:

      print(j)

      # Assigns file_name, image feature vectors and product id values of the similar item
      neighbor_file_name = file_index_to_file_name[j]
      neighbor_file_vector = file_index_to_file_vector[j]
      neighbor_product_id = file_index_to_product_id[j]

      # Calculates the similarity score of the similar item
      similarity = 1 - spatial.distance.cosine(master_vector, neighbor_file_vector)
      rounded_similarity = int((similarity * 10000)) / 10000.0

      # Appends master product id with the similarity score 
      # and the product id of the similar items
      named_nearest_neighbors.append({
        'similarity': rounded_similarity,
        'master_pi': master_product_id,
        'similar_pi': neighbor_product_id})

    print("---------------------------------") 
    print("Similarity index       : %s" %i)
    print("Master Image file name : %s" %file_index_to_file_name[i]) 
    print("Nearest Neighbors.     : %s" %nearest_neighbors) 
    print("--- %.2f minutes passed ---------" % ((time.time() - start_time)/60))

  
  print ("Step.2 - Similarity score calculation - Finished ") 

  # Writes the 'named_nearest_neighbors' to a json file
  with open('nearest_neighbors.json', 'w') as out:
    json.dump(named_nearest_neighbors, out)

  print ("Step.3 - Data stored in 'nearest_neighbors.json' file ") 
  print("--- Prosess completed in %.2f minutes ---------" % ((time.time() - start_time)/60))

cluster()
# Out:
# ---------------------------------
# Step.1 - ANNOY index generation - Started at Fri Apr  2 13:03:20 2021
# ---------------------------------
# {'imageName': '0536ef5660e47128e9fde8a25f547db0785b2851', 'productId': 'YAR45026'}
# ---------------------------------
# Annoy index     : 0
# Image file name : 0536ef5660e47128e9fde8a25f547db0785b2851
# Product id      : YAR45026
# --- 0.00 minutes passed ---------
# {'imageName': '0b0aa89982b3d9c468ef534a2f74c3fca0a4ca46', 'productId': 'YAR45081'}
# ---------------------------------
# Annoy index     : 1
# Image file name : 0b0aa89982b3d9c468ef534a2f74c3fca0a4ca46
# Product id      : YAR45081
# --- 0.00 minutes passed ---------
# {'imageName': '0b96264a36e951c2cb4fba7c3cd913fc0274cba4', 'productId': 'YAR45062'}
# ---------------------------------
# Annoy index     : 2
# Image file name : 0b96264a36e951c2cb4fba7c3cd913fc0274cba4
# Product id      : YAR45062
# --- 0.01 minutes passed ---------
# {'imageName': '114b8d92dfe9d1c38719135bc885a2220636eca3', 'productId': 'YAR45086'}
# ---------------------------------
# Annoy index     : 3
# Image file name : 114b8d92dfe9d1c38719135bc885a2220636eca3
# Product id      : YAR45086
# --- 0.01 minutes passed ---------
# {'imageName': '14f54167bfbf4393f0990334efb292242576bb51', 'productId': 'YAR45025'}
# ---------------------------------
# Annoy index     : 4
# Image file name : 14f54167bfbf4393f0990334efb292242576bb51
# Product id      : YAR45025
# --- 0.01 minutes passed ---------
# {'imageName': '158c42c84260dafc49793ce3a2e7fac1b73fba5e', 'productId': 'YAR45013'}
# ---------------------------------
# Annoy index     : 5
# Image file name : 158c42c84260dafc49793ce3a2e7fac1b73fba5e
# Product id      : YAR45013
# --- 0.01 minutes passed ---------
# {'imageName': '22abf56814e371a73528d22848889f84168dc29a', 'productId': 'YAR45010'}
# ---------------------------------
# Annoy index     : 6
# Image file name : 22abf56814e371a73528d22848889f84168dc29a
# Product id      : YAR45010
# --- 0.01 minutes passed ---------
# {'imageName': '2e7d3fa1d6bb03ec34328e705c23808f4bf11f76', 'productId': 'YAR44994'}
# ---------------------------------
# Annoy index     : 7
# Image file name : 2e7d3fa1d6bb03ec34328e705c23808f4bf11f76
# Product id      : YAR44994
# --- 0.01 minutes passed ---------
# {'imageName': '2ed31f58c2be08027b4d060dca7b80d905e9213b', 'productId': 'YAR45004'}
# ---------------------------------
# Annoy index     : 8
# Image file name : 2ed31f58c2be08027b4d060dca7b80d905e9213b
# Product id      : YAR45004
# --- 0.02 minutes passed ---------
# {'imageName': '3093418aba5897313303ae15e43275671fabe473', 'productId': 'YAR44992'}
# ---------------------------------
# Annoy index     : 9
# Image file name : 3093418aba5897313303ae15e43275671fabe473
# Product id      : YAR44992
# --- 0.02 minutes passed ---------
# {'imageName': '46921cd403370e7ab8a098843adaf29cb230537d', 'productId': 'YAR44990'}
# ---------------------------------
# Annoy index     : 10
# Image file name : 46921cd403370e7ab8a098843adaf29cb230537d
# Product id      : YAR44990
# --- 0.02 minutes passed ---------
# {'imageName': '4a2f509d8e9def9dd5681d36c3045f648dc6e1bf', 'productId': 'YAR44996'}
# ---------------------------------
# Annoy index     : 11
# Image file name : 4a2f509d8e9def9dd5681d36c3045f648dc6e1bf
# Product id      : YAR44996
# --- 0.02 minutes passed ---------
# {'imageName': '4dad9e43db72c2609856b02abced3755ef566383', 'productId': 'YAR44988'}
# ---------------------------------
# Annoy index     : 12
# Image file name : 4dad9e43db72c2609856b02abced3755ef566383
# Product id      : YAR44988
# --- 0.02 minutes passed ---------
# {'imageName': '535d914ddb7bedac122a9c158012a52defbdb28e', 'productId': 'YAR31481'}
# ---------------------------------
# Annoy index     : 13
# Image file name : 535d914ddb7bedac122a9c158012a52defbdb28e
# Product id      : YAR31481
# --- 0.02 minutes passed ---------
# {'imageName': '5b7ea4ab23dfd89d1a66ae2f256826e5c8783140', 'productId': 'YAR45066'}
# ---------------------------------
# Annoy index     : 14
# Image file name : 5b7ea4ab23dfd89d1a66ae2f256826e5c8783140
# Product id      : YAR45066
# --- 0.03 minutes passed ---------
# {'imageName': '623b50a4f2965c9fe8c453487dd288f998b51297', 'productId': 'YAR45896'}
# ---------------------------------
# Annoy index     : 15
# Image file name : 623b50a4f2965c9fe8c453487dd288f998b51297
# Product id      : YAR45896
# --- 0.03 minutes passed ---------
# {'imageName': '6e98e17cfef862fa83abdf351a23310d608b2b20', 'productId': 'YAR45028'}
# ---------------------------------
# Annoy index     : 16
# Image file name : 6e98e17cfef862fa83abdf351a23310d608b2b20
# Product id      : YAR45028
# --- 0.03 minutes passed ---------
# {'imageName': '73359c7cf3b04499250039ccb456eb168afa8704', 'productId': 'YAR45047'}
# ---------------------------------
# Annoy index     : 17
# Image file name : 73359c7cf3b04499250039ccb456eb168afa8704
# Product id      : YAR45047
# --- 0.03 minutes passed ---------
# {'imageName': '76e7932694833640c2af61030e40fd72997e7e24', 'productId': 'YAR45068'}
# ---------------------------------
# Annoy index     : 18
# Image file name : 76e7932694833640c2af61030e40fd72997e7e24
# Product id      : YAR45068
# --- 0.03 minutes passed ---------
# {'imageName': '77e23064334f0ab47f9bd17e232bdd941b2e6c1d', 'productId': 'YAR44999'}
# ---------------------------------
# Annoy index     : 19
# Image file name : 77e23064334f0ab47f9bd17e232bdd941b2e6c1d
# Product id      : YAR44999
# --- 0.03 minutes passed ---------
# {'imageName': '8893ea64a332765217b26680f925342a1bb4d301', 'productId': 'YAR45084'}
# ---------------------------------
# Annoy index     : 20
# Image file name : 8893ea64a332765217b26680f925342a1bb4d301
# Product id      : YAR45084
# --- 0.04 minutes passed ---------
# {'imageName': '8e021fac89810edd9a8529814ecab1573d68b084', 'productId': 'YAR45009'}
# ---------------------------------
# Annoy index     : 21
# Image file name : 8e021fac89810edd9a8529814ecab1573d68b084
# Product id      : YAR45009
# --- 0.04 minutes passed ---------
# {'imageName': '9769d5e06b3981d39dc1891d6da2ce8462c1c0a3', 'productId': 'YAR45041'}
# ---------------------------------
# Annoy index     : 22
# Image file name : 9769d5e06b3981d39dc1891d6da2ce8462c1c0a3
# Product id      : YAR45041
# --- 0.04 minutes passed ---------
# {'imageName': '9b79dd411d42124016196b989bdf314838f48de2', 'productId': 'YAR45067'}
# ---------------------------------
# Annoy index     : 23
# Image file name : 9b79dd411d42124016196b989bdf314838f48de2
# Product id      : YAR45067
# --- 0.04 minutes passed ---------
# {'imageName': '9e34b9687d45408f7c739e020bb38ae7e562e23f', 'productId': 'YAR45027'}
# ---------------------------------
# Annoy index     : 24
# Image file name : 9e34b9687d45408f7c739e020bb38ae7e562e23f
# Product id      : YAR45027
# --- 0.04 minutes passed ---------
# {'imageName': 'a14ac90619fa5b7feb187ead4d4d42ae9c59d7a7', 'productId': 'YAR45091'}
# ---------------------------------
# Annoy index     : 25
# Image file name : a14ac90619fa5b7feb187ead4d4d42ae9c59d7a7
# Product id      : YAR45091
# --- 0.05 minutes passed ---------
# {'imageName': 'a18b4d927b103b36451835047f7a1c223908f228', 'productId': 'YAR45016'}
# ---------------------------------
# Annoy index     : 26
# Image file name : a18b4d927b103b36451835047f7a1c223908f228
# Product id      : YAR45016
# --- 0.05 minutes passed ---------
# {'imageName': 'a940aa2eb44907bb22ad16182df5dd093b97e38c', 'productId': 'YAR45151'}
# ---------------------------------
# Annoy index     : 27
# Image file name : a940aa2eb44907bb22ad16182df5dd093b97e38c
# Product id      : YAR45151
# --- 0.05 minutes passed ---------
# {'imageName': 'a9e393eb434fe21bd20f718c4c752f819d3acba3', 'productId': 'YAR45012'}
# ---------------------------------
# Annoy index     : 28
# Image file name : a9e393eb434fe21bd20f718c4c752f819d3acba3
# Product id      : YAR45012
# --- 0.05 minutes passed ---------
# {'imageName': 'aeb31fa7538c4c38743afe3b5d181ffc2c504427', 'productId': 'YAR45005'}
# ---------------------------------
# Annoy index     : 29
# Image file name : aeb31fa7538c4c38743afe3b5d181ffc2c504427
# Product id      : YAR45005
# --- 0.05 minutes passed ---------
# {'imageName': 'b2215523a1384c5583588a831b1a008e94ab2236', 'productId': 'YAR45794'}
# ---------------------------------
# Annoy index     : 30
# Image file name : b2215523a1384c5583588a831b1a008e94ab2236
# Product id      : YAR45794
# --- 0.05 minutes passed ---------
# {'imageName': 'b3179a1855d492eb3313b59b82a1e29e8850eb92', 'productId': 'YAR45014'}
# ---------------------------------
# Annoy index     : 31
# Image file name : b3179a1855d492eb3313b59b82a1e29e8850eb92
# Product id      : YAR45014
# --- 0.06 minutes passed ---------
# {'imageName': 'b585040bac837350fe18272763a73b9ac069aa09', 'productId': 'YAR45046'}
# ---------------------------------
# Annoy index     : 32
# Image file name : b585040bac837350fe18272763a73b9ac069aa09
# Product id      : YAR45046
# --- 0.06 minutes passed ---------
# {'imageName': 'bb41ffeba7262ad30e7e76d7ba6cce2904c90782', 'productId': 'YAR45923'}
# ---------------------------------
# Annoy index     : 33
# Image file name : bb41ffeba7262ad30e7e76d7ba6cce2904c90782
# Product id      : YAR45923
# --- 0.06 minutes passed ---------
# {'imageName': 'bc5abcac7a0c9ea0e6eb2be8a6b17921fed84bdf', 'productId': 'YAR45795'}
# ---------------------------------
# Annoy index     : 34
# Image file name : bc5abcac7a0c9ea0e6eb2be8a6b17921fed84bdf
# Product id      : YAR45795
# --- 0.06 minutes passed ---------
# {'imageName': 'bfa750035da255ec6d0f71df34ac3a759e801bbf', 'productId': 'YAR31406'}
# ---------------------------------
# Annoy index     : 35
# Image file name : bfa750035da255ec6d0f71df34ac3a759e801bbf
# Product id      : YAR31406
# --- 0.06 minutes passed ---------
# {'imageName': 'c2535cf647be0949529ddb8e78beaaf79ac0bd53', 'productId': 'YAR45970'}
# ---------------------------------
# Annoy index     : 36
# Image file name : c2535cf647be0949529ddb8e78beaaf79ac0bd53
# Product id      : YAR45970
# --- 0.06 minutes passed ---------
# {'imageName': 'c2c0fff79e0b65a818412572e9f9364bc359fb4f', 'productId': 'YAR45003'}
# ---------------------------------
# Annoy index     : 37
# Image file name : c2c0fff79e0b65a818412572e9f9364bc359fb4f
# Product id      : YAR45003
# --- 0.07 minutes passed ---------
# {'imageName': 'c715c4465c351f0b06415fb9a1ccbd946327fb23', 'productId': 'YAR45061'}
# ---------------------------------
# Annoy index     : 38
# Image file name : c715c4465c351f0b06415fb9a1ccbd946327fb23
# Product id      : YAR45061
# --- 0.07 minutes passed ---------
# {'imageName': 'cba20840f15f48fae6ddaacac0721df80ae63ad8', 'productId': 'YAR45033'}
# ---------------------------------
# Annoy index     : 39
# Image file name : cba20840f15f48fae6ddaacac0721df80ae63ad8
# Product id      : YAR45033
# --- 0.07 minutes passed ---------
# {'imageName': 'cd8320501898da6979a844f621b3a97f9f76ba0c', 'productId': 'YAR31474'}
# ---------------------------------
# Annoy index     : 40
# Image file name : cd8320501898da6979a844f621b3a97f9f76ba0c
# Product id      : YAR31474
# --- 0.07 minutes passed ---------
# {'imageName': 'd8b30ba9b6f342c670ca0086857926cbbad4508d', 'productId': 'YAR44997'}
# ---------------------------------
# Annoy index     : 41
# Image file name : d8b30ba9b6f342c670ca0086857926cbbad4508d
# Product id      : YAR44997
# --- 0.07 minutes passed ---------
# {'imageName': 'dc09ad64aa6f60ae863d2547652d89d2a1e4f508', 'productId': 'YAR44995'}
# ---------------------------------
# Annoy index     : 42
# Image file name : dc09ad64aa6f60ae863d2547652d89d2a1e4f508
# Product id      : YAR44995
# --- 0.08 minutes passed ---------
# {'imageName': 'e5dddf21df0ffefc2b3b6848c701b28d42477dec', 'productId': 'YAR31435'}
# ---------------------------------
# Annoy index     : 43
# Image file name : e5dddf21df0ffefc2b3b6848c701b28d42477dec
# Product id      : YAR31435
# --- 0.08 minutes passed ---------
# {'imageName': 'e95a8e4c52075aaa389d3d2b031c39c5570a1d99', 'productId': 'YAR45034'}
# ---------------------------------
# Annoy index     : 44
# Image file name : e95a8e4c52075aaa389d3d2b031c39c5570a1d99
# Product id      : YAR45034
# --- 0.08 minutes passed ---------
# {'imageName': 'f170378bdd1be7568992468443d7454e1f3d24f9', 'productId': 'YAR45035'}
# ---------------------------------
# Annoy index     : 45
# Image file name : f170378bdd1be7568992468443d7454e1f3d24f9
# Product id      : YAR45035
# --- 0.08 minutes passed ---------
# {'imageName': 'f4748df6bae208df39ac33e4d2e88ef51673666a', 'productId': 'YAR45036'}
# ---------------------------------
# Annoy index     : 46
# Image file name : f4748df6bae208df39ac33e4d2e88ef51673666a
# Product id      : YAR45036
# --- 0.08 minutes passed ---------
# {'imageName': 'f5d05c38a69a94a93fec7e8ee357d701dc2308d9', 'productId': 'YAR45083'}
# ---------------------------------
# Annoy index     : 47
# Image file name : f5d05c38a69a94a93fec7e8ee357d701dc2308d9
# Product id      : YAR45083
# --- 0.09 minutes passed ---------
# {'imageName': 'f7aaabd886d4f7b8736dcb4055abd94301dc846d', 'productId': 'YAR45022'}
# ---------------------------------
# Annoy index     : 48
# Image file name : f7aaabd886d4f7b8736dcb4055abd94301dc846d
# Product id      : YAR45022
# --- 0.09 minutes passed ---------
# {'imageName': 'fd27283a5a01a7a4d4b153d4de4b38117a94f4b8', 'productId': 'YAR45065'}
# ---------------------------------
# Annoy index     : 49
# Image file name : fd27283a5a01a7a4d4b153d4de4b38117a94f4b8
# Product id      : YAR45065
# --- 0.09 minutes passed ---------
# Step.1 - ANNOY index generation - Finished
# Step.2 - Similarity score calculation - Started
# 0
# 15
# 7
# 46
# 37
# 26
# 39
# 22
# 24
# 40
# 1
# 3
# 36
# 28
# 44
# 23
# 14
# 49
# 5
# 25
# ---------------------------------
# Similarity index       : 0
# Master Image file name : 0536ef5660e47128e9fde8a25f547db0785b2851
# Nearest Neighbors.     : [0, 15, 7, 46, 37, 26, 39, 22, 24, 40, 1, 3, 36, 28, 44, 23, 14, 49, 5, 25]
# --- 0.10 minutes passed ---------
# 1
# 3
# 47
# 24
# 30
# 41
# 25
# 28
# 43
# 39
# 21
# 9
# 0
# 22
# 36
# 40
# 17
# 46
# 45
# 15
# ---------------------------------
# Similarity index       : 1
# Master Image file name : 0b0aa89982b3d9c468ef534a2f74c3fca0a4ca46
# Nearest Neighbors.     : [1, 3, 47, 24, 30, 41, 25, 28, 43, 39, 21, 9, 0, 22, 36, 40, 17, 46, 45, 15]
# --- 0.10 minutes passed ---------
# 2
# 18
# 45
# 33
# 43
# 27
# 34
# 19
# 17
# 38
# 4
# 14
# 49
# 47
# 13
# 8
# 30
# 22
# 46
# 24
# ---------------------------------
# Similarity index       : 2
# Master Image file name : 0b96264a36e951c2cb4fba7c3cd913fc0274cba4
# Nearest Neighbors.     : [2, 18, 45, 33, 43, 27, 34, 19, 17, 38, 4, 14, 49, 47, 13, 8, 30, 22, 46, 24]
# --- 0.10 minutes passed ---------
# 3
# 1
# 25
# 22
# 28
# 8
# 20
# 24
# 39
# 15
# 44
# 35
# 46
# 47
# 0
# 21
# 36
# 23
# 30
# 9
# ---------------------------------
# Similarity index       : 3
# Master Image file name : 114b8d92dfe9d1c38719135bc885a2220636eca3
# Nearest Neighbors.     : [3, 1, 25, 22, 28, 8, 20, 24, 39, 15, 44, 35, 46, 47, 0, 21, 36, 23, 30, 9]
# --- 0.10 minutes passed ---------
# 4
# 27
# 33
# 19
# 8
# 45
# 43
# 18
# 38
# 41
# 34
# 47
# 2
# 44
# 22
# 36
# 32
# 7
# 40
# 13
# ---------------------------------
# Similarity index       : 4
# Master Image file name : 14f54167bfbf4393f0990334efb292242576bb51
# Nearest Neighbors.     : [4, 27, 33, 19, 8, 45, 43, 18, 38, 41, 34, 47, 2, 44, 22, 36, 32, 7, 40, 13]
# --- 0.10 minutes passed ---------
# 5
# 10
# 48
# 29
# 7
# 37
# 44
# 39
# 11
# 0
# 6
# 23
# 42
# 22
# 4
# 46
# 13
# 49
# 14
# 38
# ---------------------------------
# Similarity index       : 5
# Master Image file name : 158c42c84260dafc49793ce3a2e7fac1b73fba5e
# Nearest Neighbors.     : [5, 10, 48, 29, 7, 37, 44, 39, 11, 0, 6, 23, 42, 22, 4, 46, 13, 49, 14, 38]
# --- 0.10 minutes passed ---------
# 6
# 11
# 44
# 23
# 48
# 14
# 37
# 5
# 29
# 10
# 32
# 39
# 38
# 7
# 36
# 49
# 22
# 21
# 0
# 28
# ---------------------------------
# Similarity index       : 6
# Master Image file name : 22abf56814e371a73528d22848889f84168dc29a
# Nearest Neighbors.     : [6, 11, 44, 23, 48, 14, 37, 5, 29, 10, 32, 39, 38, 7, 36, 49, 22, 21, 0, 28]
# --- 0.10 minutes passed ---------
# 7
# 37
# 0
# 5
# 15
# 42
# 26
# 44
# 48
# 22
# 49
# 40
# 10
# 46
# 39
# 14
# 29
# 36
# 4
# 8
# ---------------------------------
# Similarity index       : 7
# Master Image file name : 2e7d3fa1d6bb03ec34328e705c23808f4bf11f76
# Nearest Neighbors.     : [7, 37, 0, 5, 15, 42, 26, 44, 48, 22, 49, 40, 10, 46, 39, 14, 29, 36, 4, 8]
# --- 0.10 minutes passed ---------
# 8
# 22
# 25
# 38
# 44
# 28
# 46
# 23
# 49
# 39
# 21
# 36
# 14
# 3
# 4
# 32
# 20
# 34
# 24
# 45
# ---------------------------------
# Similarity index       : 8
# Master Image file name : 2ed31f58c2be08027b4d060dca7b80d905e9213b
# Nearest Neighbors.     : [8, 22, 25, 38, 44, 28, 46, 23, 49, 39, 21, 36, 14, 3, 4, 32, 20, 34, 24, 45]
# --- 0.10 minutes passed ---------
# 9
# 47
# 40
# 17
# 35
# 1
# 12
# 31
# 45
# 34
# 18
# 24
# 30
# 3
# 41
# 39
# 8
# 20
# 43
# 15
# ---------------------------------
# Similarity index       : 9
# Master Image file name : 3093418aba5897313303ae15e43275671fabe473
# Nearest Neighbors.     : [9, 47, 40, 17, 35, 1, 12, 31, 45, 34, 18, 24, 30, 3, 41, 39, 8, 20, 43, 15]
# --- 0.10 minutes passed ---------
# 10
# 48
# 5
# 29
# 37
# 44
# 11
# 39
# 23
# 7
# 6
# 0
# 31
# 40
# 14
# 49
# 42
# 38
# 46
# 13
# ---------------------------------
# Similarity index       : 10
# Master Image file name : 46921cd403370e7ab8a098843adaf29cb230537d
# Nearest Neighbors.     : [10, 48, 5, 29, 37, 44, 11, 39, 23, 7, 6, 0, 31, 40, 14, 49, 42, 38, 46, 13]
# --- 0.10 minutes passed ---------
# 11
# 23
# 44
# 39
# 48
# 6
# 10
# 21
# 37
# 8
# 14
# 25
# 22
# 5
# 28
# 36
# 3
# 32
# 0
# 49
# ---------------------------------
# Similarity index       : 11
# Master Image file name : 4a2f509d8e9def9dd5681d36c3045f648dc6e1bf
# Nearest Neighbors.     : [11, 23, 44, 39, 48, 6, 10, 21, 37, 8, 14, 25, 22, 5, 28, 36, 3, 32, 0, 49]
# --- 0.10 minutes passed ---------
# 12
# 13
# 31
# 9
# 17
# 40
# 34
# 35
# 20
# 49
# 24
# 18
# 8
# 14
# 47
# 42
# 44
# 45
# 46
# 15
# ---------------------------------
# Similarity index       : 12
# Master Image file name : 4dad9e43db72c2609856b02abced3755ef566383
# Nearest Neighbors.     : [12, 13, 31, 9, 17, 40, 34, 35, 20, 49, 24, 18, 8, 14, 47, 42, 44, 45, 46, 15]
# --- 0.10 minutes passed ---------
# 13
# 12
# 49
# 40
# 42
# 31
# 17
# 38
# 14
# 22
# 18
# 43
# 46
# 45
# 19
# 26
# 44
# 4
# 36
# 2
# ---------------------------------
# Similarity index       : 13
# Master Image file name : 535d914ddb7bedac122a9c158012a52defbdb28e
# Nearest Neighbors.     : [13, 12, 49, 40, 42, 31, 17, 38, 14, 22, 18, 43, 46, 45, 19, 26, 44, 4, 36, 2]
# --- 0.10 minutes passed ---------
# 14
# 49
# 38
# 44
# 22
# 36
# 23
# 39
# 28
# 25
# 32
# 8
# 46
# 43
# 37
# 42
# 20
# 34
# 13
# 45
# ---------------------------------
# Similarity index       : 14
# Master Image file name : 5b7ea4ab23dfd89d1a66ae2f256826e5c8783140
# Nearest Neighbors.     : [14, 49, 38, 44, 22, 36, 23, 39, 28, 25, 32, 8, 46, 43, 37, 42, 20, 34, 13, 45]
# --- 0.10 minutes passed ---------
# 15
# 0
# 26
# 46
# 24
# 22
# 40
# 7
# 3
# 28
# 8
# 39
# 1
# 36
# 47
# 25
# 20
# 31
# 17
# 37
# ---------------------------------
# Similarity index       : 15
# Master Image file name : 623b50a4f2965c9fe8c453487dd288f998b51297
# Nearest Neighbors.     : [15, 0, 26, 46, 24, 22, 40, 7, 3, 28, 8, 39, 1, 36, 47, 25, 20, 31, 17, 37]
# --- 0.10 minutes passed ---------
# 16
# 35
# 1
# 3
# 47
# 9
# 4
# 41
# 8
# 39
# 48
# 44
# 21
# 40
# 5
# 17
# 23
# 27
# 45
# 20
# ---------------------------------
# Similarity index       : 16
# Master Image file name : 6e98e17cfef862fa83abdf351a23310d608b2b20
# Nearest Neighbors.     : [16, 35, 1, 3, 47, 9, 4, 41, 8, 39, 48, 44, 21, 40, 5, 17, 23, 27, 45, 20]
# --- 0.10 minutes passed ---------
# 17
# 34
# 18
# 47
# 24
# 40
# 45
# 9
# 2
# 22
# 20
# 43
# 19
# 1
# 12
# 13
# 26
# 30
# 41
# 46
# ---------------------------------
# Similarity index       : 17
# Master Image file name : 73359c7cf3b04499250039ccb456eb168afa8704
# Nearest Neighbors.     : [17, 34, 18, 47, 24, 40, 45, 9, 2, 22, 20, 43, 19, 1, 12, 13, 26, 30, 41, 46]
# --- 0.10 minutes passed ---------
# 18
# 2
# 45
# 33
# 34
# 17
# 27
# 19
# 43
# 4
# 47
# 8
# 24
# 9
# 30
# 38
# 13
# 40
# 12
# 1
# ---------------------------------
# Similarity index       : 18
# Master Image file name : 76e7932694833640c2af61030e40fd72997e7e24
# Nearest Neighbors.     : [18, 2, 45, 33, 34, 17, 27, 19, 43, 4, 47, 8, 24, 9, 30, 38, 13, 40, 12, 1]
# --- 0.10 minutes passed ---------
# 19
# 33
# 43
# 27
# 4
# 45
# 18
# 2
# 40
# 47
# 38
# 26
# 17
# 22
# 41
# 8
# 36
# 34
# 14
# 46
# ---------------------------------
# Similarity index       : 19
# Master Image file name : 77e23064334f0ab47f9bd17e232bdd941b2e6c1d
# Nearest Neighbors.     : [19, 33, 43, 27, 4, 45, 18, 2, 40, 47, 38, 26, 17, 22, 41, 8, 36, 34, 14, 46]
# --- 0.10 minutes passed ---------
# 20
# 3
# 47
# 22
# 24
# 34
# 8
# 25
# 17
# 14
# 46
# 28
# 21
# 31
# 36
# 41
# 49
# 38
# 44
# 40
# ---------------------------------
# Similarity index       : 20
# Master Image file name : 8893ea64a332765217b26680f925342a1bb4d301
# Nearest Neighbors.     : [20, 3, 47, 22, 24, 34, 8, 25, 17, 14, 46, 28, 21, 31, 36, 41, 49, 38, 44, 40]
# --- 0.10 minutes passed ---------
# 21
# 28
# 25
# 8
# 39
# 23
# 32
# 46
# 44
# 36
# 1
# 11
# 3
# 20
# 22
# 24
# 45
# 41
# 47
# 34
# ---------------------------------
# Similarity index       : 21
# Master Image file name : 8e021fac89810edd9a8529814ecab1573d68b084
# Nearest Neighbors.     : [21, 28, 25, 8, 39, 23, 32, 46, 44, 36, 1, 11, 3, 20, 22, 24, 45, 41, 47, 34]
# --- 0.10 minutes passed ---------
# 22
# 36
# 49
# 14
# 46
# 8
# 38
# 25
# 28
# 44
# 39
# 32
# 15
# 3
# 23
# 24
# 43
# 20
# 0
# 17
# ---------------------------------
# Similarity index       : 22
# Master Image file name : 9769d5e06b3981d39dc1891d6da2ce8462c1c0a3
# Nearest Neighbors.     : [22, 36, 49, 14, 46, 8, 38, 25, 28, 44, 39, 32, 15, 3, 23, 24, 43, 20, 0, 17]
# --- 0.10 minutes passed ---------
# 23
# 39
# 44
# 11
# 14
# 38
# 49
# 8
# 28
# 25
# 46
# 48
# 21
# 22
# 32
# 36
# 6
# 3
# 37
# 0
# ---------------------------------
# Similarity index       : 23
# Master Image file name : 9b79dd411d42124016196b989bdf314838f48de2
# Nearest Neighbors.     : [23, 39, 44, 11, 14, 38, 49, 8, 28, 25, 46, 48, 21, 22, 32, 36, 6, 3, 37, 0]
# --- 0.10 minutes passed ---------
# 24
# 1
# 47
# 15
# 22
# 41
# 17
# 3
# 30
# 40
# 36
# 20
# 0
# 34
# 8
# 46
# 28
# 18
# 25
# 43
# ---------------------------------
# Similarity index       : 24
# Master Image file name : 9e34b9687d45408f7c739e020bb38ae7e562e23f
# Nearest Neighbors.     : [24, 1, 47, 15, 22, 41, 17, 3, 30, 40, 36, 20, 0, 34, 8, 46, 28, 18, 25, 43]
# --- 0.10 minutes passed ---------
# 25
# 36
# 28
# 22
# 44
# 21
# 8
# 3
# 14
# 46
# 38
# 23
# 1
# 49
# 39
# 32
# 20
# 47
# 24
# 43
# ---------------------------------
# Similarity index       : 25
# Master Image file name : a14ac90619fa5b7feb187ead4d4d42ae9c59d7a7
# Nearest Neighbors.     : [25, 36, 28, 22, 44, 21, 8, 3, 14, 46, 38, 23, 1, 49, 39, 32, 20, 47, 24, 43]
# --- 0.10 minutes passed ---------
# 26
# 15
# 0
# 40
# 7
# 19
# 17
# 46
# 22
# 24
# 47
# 43
# 1
# 41
# 30
# 18
# 45
# 13
# 36
# 34
# ---------------------------------
# Similarity index       : 26
# Master Image file name : a18b4d927b103b36451835047f7a1c223908f228
# Nearest Neighbors.     : [26, 15, 0, 40, 7, 19, 17, 46, 22, 24, 47, 43, 1, 41, 30, 18, 45, 13, 36, 34]
# --- 0.10 minutes passed ---------
# 27
# 33
# 4
# 19
# 18
# 45
# 2
# 43
# 8
# 47
# 38
# 17
# 34
# 25
# 1
# 36
# 21
# 41
# 22
# 40
# ---------------------------------
# Similarity index       : 27
# Master Image file name : a940aa2eb44907bb22ad16182df5dd093b97e38c
# Nearest Neighbors.     : [27, 33, 4, 19, 18, 45, 2, 43, 8, 47, 38, 17, 34, 25, 1, 36, 21, 41, 22, 40]
# --- 0.10 minutes passed ---------
# 28
# 25
# 36
# 46
# 21
# 22
# 39
# 8
# 32
# 14
# 44
# 23
# 3
# 49
# 38
# 1
# 15
# 24
# 20
# 0
# ---------------------------------
# Similarity index       : 28
# Master Image file name : a9e393eb434fe21bd20f718c4c752f819d3acba3
# Nearest Neighbors.     : [28, 25, 36, 46, 21, 22, 39, 8, 32, 14, 44, 23, 3, 49, 38, 1, 15, 24, 20, 0]
# --- 0.10 minutes passed ---------
# 29
# 10
# 5
# 37
# 48
# 44
# 7
# 6
# 23
# 11
# 42
# 38
# 39
# 14
# 49
# 13
# 0
# 32
# 4
# 40
# ---------------------------------
# Similarity index       : 29
# Master Image file name : aeb31fa7538c4c38743afe3b5d181ffc2c504427
# Nearest Neighbors.     : [29, 10, 5, 37, 48, 44, 7, 6, 23, 11, 42, 38, 39, 14, 49, 13, 0, 32, 4, 40]
# --- 0.10 minutes passed ---------
# 30
# 1
# 41
# 47
# 45
# 34
# 24
# 43
# 18
# 17
# 3
# 9
# 40
# 21
# 46
# 26
# 28
# 39
# 0
# 19
# ---------------------------------
# Similarity index       : 30
# Master Image file name : b2215523a1384c5583588a831b1a008e94ab2236
# Nearest Neighbors.     : [30, 1, 41, 47, 45, 34, 24, 43, 18, 17, 3, 9, 40, 21, 46, 26, 28, 39, 0, 19]
# --- 0.10 minutes passed ---------
# 31
# 35
# 40
# 12
# 13
# 49
# 9
# 46
# 39
# 20
# 22
# 24
# 44
# 8
# 14
# 15
# 48
# 23
# 3
# 17
# ---------------------------------
# Similarity index       : 31
# Master Image file name : b3179a1855d492eb3313b59b82a1e29e8850eb92
# Nearest Neighbors.     : [31, 35, 40, 12, 13, 49, 9, 46, 39, 20, 22, 24, 44, 8, 14, 15, 48, 23, 3, 17]
# --- 0.10 minutes passed ---------
# 32
# 44
# 38
# 28
# 39
# 46
# 49
# 14
# 22
# 36
# 23
# 21
# 8
# 25
# 45
# 34
# 37
# 4
# 41
# 11
# ---------------------------------
# Similarity index       : 32
# Master Image file name : b585040bac837350fe18272763a73b9ac069aa09
# Nearest Neighbors.     : [32, 44, 38, 28, 39, 46, 49, 14, 22, 36, 23, 21, 8, 25, 45, 34, 37, 4, 41, 11]
# --- 0.10 minutes passed ---------
# 33
# 27
# 19
# 18
# 4
# 2
# 45
# 43
# 8
# 17
# 38
# 47
# 34
# 22
# 26
# 1
# 13
# 39
# 46
# 32
# ---------------------------------
# Similarity index       : 33
# Master Image file name : bb41ffeba7262ad30e7e76d7ba6cce2904c90782
# Nearest Neighbors.     : [33, 27, 19, 18, 4, 2, 45, 43, 8, 17, 38, 47, 34, 22, 26, 1, 13, 39, 46, 32]
# --- 0.10 minutes passed ---------
# 34
# 45
# 47
# 18
# 17
# 41
# 30
# 43
# 2
# 20
# 8
# 24
# 38
# 9
# 36
# 39
# 14
# 22
# 28
# 49
# ---------------------------------
# Similarity index       : 34
# Master Image file name : bc5abcac7a0c9ea0e6eb2be8a6b17921fed84bdf
# Nearest Neighbors.     : [34, 45, 47, 18, 17, 41, 30, 43, 2, 20, 8, 24, 38, 9, 36, 39, 14, 22, 28, 49]
# --- 0.10 minutes passed ---------
# 35
# 31
# 9
# 3
# 40
# 8
# 16
# 12
# 39
# 20
# 47
# 1
# 24
# 48
# 46
# 22
# 23
# 25
# 15
# 44
# ---------------------------------
# Similarity index       : 35
# Master Image file name : bfa750035da255ec6d0f71df34ac3a759e801bbf
# Nearest Neighbors.     : [35, 31, 9, 3, 40, 8, 16, 12, 39, 20, 47, 1, 24, 48, 46, 22, 23, 25, 15, 44]
# --- 0.11 minutes passed ---------
# 36
# 22
# 25
# 14
# 28
# 49
# 38
# 44
# 46
# 8
# 32
# 39
# 23
# 24
# 43
# 21
# 0
# 1
# 3
# 34
# ---------------------------------
# Similarity index       : 36
# Master Image file name : c2535cf647be0949529ddb8e78beaaf79ac0bd53
# Nearest Neighbors.     : [36, 22, 25, 14, 28, 49, 38, 44, 46, 8, 32, 39, 23, 24, 43, 21, 0, 1, 3, 34]
# --- 0.11 minutes passed ---------
# 37
# 7
# 0
# 44
# 42
# 5
# 10
# 49
# 29
# 48
# 14
# 11
# 22
# 23
# 39
# 38
# 32
# 6
# 36
# 15
# ---------------------------------
# Similarity index       : 37
# Master Image file name : c2c0fff79e0b65a818412572e9f9364bc359fb4f
# Nearest Neighbors.     : [37, 7, 0, 44, 42, 5, 10, 49, 29, 48, 14, 11, 22, 23, 39, 38, 32, 6, 36, 15]
# --- 0.11 minutes passed ---------
# 38
# 14
# 49
# 44
# 22
# 36
# 8
# 23
# 32
# 39
# 43
# 25
# 46
# 45
# 28
# 34
# 42
# 19
# 2
# 4
# ---------------------------------
# Similarity index       : 38
# Master Image file name : c715c4465c351f0b06415fb9a1ccbd946327fb23
# Nearest Neighbors.     : [38, 14, 49, 44, 22, 36, 8, 23, 32, 39, 43, 25, 46, 45, 28, 34, 42, 19, 2, 4]
# --- 0.11 minutes passed ---------
# 39
# 23
# 44
# 46
# 28
# 14
# 11
# 38
# 49
# 22
# 32
# 8
# 21
# 36
# 0
# 25
# 3
# 1
# 48
# 41
# ---------------------------------
# Similarity index       : 39
# Master Image file name : cba20840f15f48fae6ddaacac0721df80ae63ad8
# Nearest Neighbors.     : [39, 23, 44, 46, 28, 14, 11, 38, 49, 22, 32, 8, 21, 36, 0, 25, 3, 1, 48, 41]
# --- 0.11 minutes passed ---------
# 40
# 47
# 43
# 9
# 26
# 15
# 45
# 31
# 17
# 24
# 46
# 41
# 13
# 0
# 19
# 35
# 1
# 22
# 49
# 12
# ---------------------------------
# Similarity index       : 40
# Master Image file name : cd8320501898da6979a844f621b3a97f9f76ba0c
# Nearest Neighbors.     : [40, 47, 43, 9, 26, 15, 45, 31, 17, 24, 46, 41, 13, 0, 19, 35, 1, 22, 49, 12]
# --- 0.11 minutes passed ---------
# 41
# 47
# 30
# 34
# 1
# 45
# 24
# 43
# 40
# 39
# 46
# 4
# 19
# 8
# 20
# 21
# 17
# 3
# 9
# 22
# ---------------------------------
# Similarity index       : 41
# Master Image file name : d8b30ba9b6f342c670ca0086857926cbbad4508d
# Nearest Neighbors.     : [41, 47, 30, 34, 1, 45, 24, 43, 40, 39, 46, 4, 19, 8, 20, 21, 17, 3, 9, 22]
# --- 0.11 minutes passed ---------
# 42
# 49
# 37
# 7
# 38
# 13
# 14
# 22
# 44
# 36
# 46
# 24
# 0
# 5
# 40
# 23
# 8
# 12
# 48
# 39
# ---------------------------------
# Similarity index       : 42
# Master Image file name : dc09ad64aa6f60ae863d2547652d89d2a1e4f508
# Nearest Neighbors.     : [42, 49, 37, 7, 38, 13, 14, 22, 44, 36, 46, 24, 0, 5, 40, 23, 8, 12, 48, 39]
# --- 0.11 minutes passed ---------
# 43
# 19
# 45
# 47
# 38
# 40
# 22
# 2
# 34
# 4
# 14
# 18
# 41
# 1
# 36
# 33
# 27
# 49
# 46
# 17
# ---------------------------------
# Similarity index       : 43
# Master Image file name : e5dddf21df0ffefc2b3b6848c701b28d42477dec
# Nearest Neighbors.     : [43, 19, 45, 47, 38, 40, 22, 2, 34, 4, 14, 18, 41, 1, 36, 33, 27, 49, 46, 17]
# --- 0.11 minutes passed ---------
# 44
# 23
# 38
# 14
# 39
# 49
# 25
# 22
# 32
# 8
# 36
# 11
# 28
# 48
# 46
# 37
# 21
# 6
# 3
# 10
# ---------------------------------
# Similarity index       : 44
# Master Image file name : e95a8e4c52075aaa389d3d2b031c39c5570a1d99
# Nearest Neighbors.     : [44, 23, 38, 14, 39, 49, 25, 22, 32, 8, 36, 11, 28, 48, 46, 37, 21, 6, 3, 10]
# --- 0.11 minutes passed ---------
# 45
# 34
# 18
# 43
# 2
# 47
# 19
# 30
# 41
# 38
# 27
# 4
# 33
# 40
# 17
# 8
# 32
# 9
# 46
# 1
# ---------------------------------
# Similarity index       : 45
# Master Image file name : f170378bdd1be7568992468443d7454e1f3d24f9
# Nearest Neighbors.     : [45, 34, 18, 43, 2, 47, 19, 30, 41, 38, 27, 4, 33, 40, 17, 8, 32, 9, 46, 1]
# --- 0.11 minutes passed ---------
# 46
# 39
# 22
# 28
# 49
# 36
# 8
# 32
# 25
# 44
# 15
# 0
# 23
# 14
# 38
# 21
# 40
# 24
# 3
# 43
# ---------------------------------
# Similarity index       : 46
# Master Image file name : f4748df6bae208df39ac33e4d2e88ef51673666a
# Nearest Neighbors.     : [46, 39, 22, 28, 49, 36, 8, 32, 25, 44, 15, 0, 23, 14, 38, 21, 40, 24, 3, 43]
# --- 0.11 minutes passed ---------
# 47
# 34
# 1
# 41
# 43
# 45
# 30
# 40
# 9
# 24
# 17
# 20
# 18
# 3
# 19
# 25
# 22
# 8
# 28
# 36
# ---------------------------------
# Similarity index       : 47
# Master Image file name : f5d05c38a69a94a93fec7e8ee357d701dc2308d9
# Nearest Neighbors.     : [47, 34, 1, 41, 43, 45, 30, 40, 9, 24, 17, 20, 18, 3, 19, 25, 22, 8, 28, 36]
# --- 0.11 minutes passed ---------
# 48
# 10
# 5
# 44
# 23
# 11
# 37
# 29
# 39
# 7
# 6
# 35
# 8
# 38
# 31
# 14
# 22
# 25
# 0
# 49
# ---------------------------------
# Similarity index       : 48
# Master Image file name : f7aaabd886d4f7b8736dcb4055abd94301dc846d
# Nearest Neighbors.     : [48, 10, 5, 44, 23, 11, 37, 29, 39, 7, 6, 35, 8, 38, 31, 14, 22, 25, 0, 49]
# --- 0.11 minutes passed ---------
# 49
# 14
# 38
# 22
# 44
# 36
# 46
# 39
# 23
# 32
# 8
# 42
# 28
# 25
# 13
# 37
# 43
# 31
# 40
# 45
# ---------------------------------
# Similarity index       : 49
# Master Image file name : fd27283a5a01a7a4d4b153d4de4b38117a94f4b8
# Nearest Neighbors.     : [49, 14, 38, 22, 44, 36, 46, 39, 23, 32, 8, 42, 28, 25, 13, 37, 43, 31, 40, 45]
# --- 0.11 minutes passed ---------
# Step.2 - Similarity score calculation - Finished
# Step.3 - Data stored in 'nearest_neighbors.json' file
# --- Prosess completed in 0.11 minutes ---------

# %%
#################################################
# Imports and function definitions
#################################################
# For running inference on the TF-Hub module.
import tensorflow as tf
import tensorflow_hub as hub

# For saving 'feature vectors' into a txt file
import numpy as np

# Time for measuring the process time
import time

# Glob for reading file names in a folder
import glob
import os.path
#################################################

#################################################
# This function:
# Loads the JPEG image at the given path
# Decodes the JPEG image to a uint8 W X H X 3 tensor
# Resizes the image to 224 x 224 x 3 tensor
# Returns the pre processed image as 224 x 224 x 3 tensor
#################################################
def load_img(path):

  # Reads the image file and returns data type of string
  img = tf.io.read_file(path)

  # Decodes the image to W x H x 3 shape tensor with type of uint8
  img = tf.io.decode_jpeg(img, channels=3)

  # Resize the image to 224 x 244 x 3 shape tensor
  img = tf.image.resize_with_pad(img, 224, 224)

  # Converts the data type of uint8 to float32 by adding a new axis
  # This makes the img 1 x 224 x 224 x 3 tensor with the data type of float32
  # This is required for the mobilenet model we are using
  img  = tf.image.convert_image_dtype(img, tf.float32)[tf.newaxis, ...]

  return img

#################################################
# This function:
# Loads the mobilenet model in TF.HUB
# Makes an inference for all images stored in a local folder
# Saves each of the feature vectors in a file
#################################################
def get_image_feature_vectors():

  i = 0

  start_time = time.time()

  print("---------------------------------")
  print ("Step.1 of 2 - mobilenet_v2_140_224 - Loading Started at %s" %time.ctime())
  print("---------------------------------")

  # Definition of module with using tfhub.dev handle
  module_handle = "https://tfhub.dev/google/imagenet/mobilenet_v2_140_224/feature_vector/4" 
  
  # Load the module
  module = hub.load(module_handle)

  print("---------------------------------")
  print ("Step.1 of 2 - mobilenet_v2_140_224 - Loading Completed at %s" %time.ctime())
  print("--- %.2f minutes passed ---------" % ((time.time() - start_time)/60))

  print("---------------------------------")
  print ("Step.2 of 2 - Generating Feature Vectors -  Started at %s" %time.ctime())
 

  # Loops through all images in a local folder
  for filename in glob.glob('E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test/*.jpg'): #assuming gif
    i = i + 1

    print("-----------------------------------------------------------------------------------------")
    print("Image count                     :%s" %i)
    print("Image in process is             :%s" %filename)

    # Loads and pre-process the image
    img = load_img(filename)

    # Calculate the image feature vector of the img
    features = module(img)   
  
    # Remove single-dimensional entries from the 'features' array
    feature_set = np.squeeze(features)  

    # Saves the image feature vectors into a file for later use

    outfile_name = os.path.basename(filename).split('.')[0] + ".npz"
    out_path = os.path.join('E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test/', outfile_name)

    # Saves the 'feature_set' to a text file
    np.savetxt(out_path, feature_set, delimiter=',')

    print("Image feature vector saved to   :%s" %out_path)
  
  print("---------------------------------")
  print ("Step.2 of 2 - Generating Feature Vectors - Completed at %s" %time.ctime())
  print("--- %.2f minutes passed ---------" % ((time.time() - start_time)/60))
  print("--- %s images processed ---------" %i)
    
get_image_feature_vectors()
# Out:
# ---------------------------------
# Step.1 of 2 - mobilenet_v2_140_224 - Loading Started at Fri Apr  2 12:57:49 2021
# ---------------------------------
# ---------------------------------
# Step.1 of 2 - mobilenet_v2_140_224 - Loading Completed at Fri Apr  2 12:57:56 2021
# --- 0.13 minutes passed ---------
# ---------------------------------
# Step.2 of 2 - Generating Feature Vectors -  Started at Fri Apr  2 12:57:56 2021
# -----------------------------------------------------------------------------------------
# Image count                     :1
# Image in process is             :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test\0536ef5660e47128e9fde8a25f547db0785b2851.jpg
# Image feature vector saved to   :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test/0536ef5660e47128e9fde8a25f547db0785b2851.npz
# -----------------------------------------------------------------------------------------
# Image count                     :2
# Image in process is             :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test\0b0aa89982b3d9c468ef534a2f74c3fca0a4ca46.jpg
# Image feature vector saved to   :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test/0b0aa89982b3d9c468ef534a2f74c3fca0a4ca46.npz
# -----------------------------------------------------------------------------------------
# Image count                     :3
# Image in process is             :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test\0b96264a36e951c2cb4fba7c3cd913fc0274cba4.jpg
# Image feature vector saved to   :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test/0b96264a36e951c2cb4fba7c3cd913fc0274cba4.npz
# -----------------------------------------------------------------------------------------
# Image count                     :4
# Image in process is             :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test\114b8d92dfe9d1c38719135bc885a2220636eca3.jpg
# Image feature vector saved to   :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test/114b8d92dfe9d1c38719135bc885a2220636eca3.npz
# -----------------------------------------------------------------------------------------
# Image count                     :5
# Image in process is             :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test\14f54167bfbf4393f0990334efb292242576bb51.jpg
# Image feature vector saved to   :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test/14f54167bfbf4393f0990334efb292242576bb51.npz
# -----------------------------------------------------------------------------------------
# Image count                     :6
# Image in process is             :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test\158c42c84260dafc49793ce3a2e7fac1b73fba5e.jpg
# Image feature vector saved to   :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test/158c42c84260dafc49793ce3a2e7fac1b73fba5e.npz
# -----------------------------------------------------------------------------------------
# Image count                     :7
# Image in process is             :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test\22abf56814e371a73528d22848889f84168dc29a.jpg
# Image feature vector saved to   :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test/22abf56814e371a73528d22848889f84168dc29a.npz
# -----------------------------------------------------------------------------------------
# Image count                     :8
# Image in process is             :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test\2e7d3fa1d6bb03ec34328e705c23808f4bf11f76.jpg
# Image feature vector saved to   :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test/2e7d3fa1d6bb03ec34328e705c23808f4bf11f76.npz
# -----------------------------------------------------------------------------------------
# Image count                     :9
# Image in process is             :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test\2ed31f58c2be08027b4d060dca7b80d905e9213b.jpg
# Image feature vector saved to   :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test/2ed31f58c2be08027b4d060dca7b80d905e9213b.npz
# -----------------------------------------------------------------------------------------
# Image count                     :10
# Image in process is             :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test\3093418aba5897313303ae15e43275671fabe473.jpg
# Image feature vector saved to   :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test/3093418aba5897313303ae15e43275671fabe473.npz
# -----------------------------------------------------------------------------------------
# Image count                     :11
# Image in process is             :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test\46921cd403370e7ab8a098843adaf29cb230537d.jpg
# Image feature vector saved to   :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test/46921cd403370e7ab8a098843adaf29cb230537d.npz
# -----------------------------------------------------------------------------------------
# Image count                     :12
# Image in process is             :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test\4a2f509d8e9def9dd5681d36c3045f648dc6e1bf.jpg
# Image feature vector saved to   :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test/4a2f509d8e9def9dd5681d36c3045f648dc6e1bf.npz
# -----------------------------------------------------------------------------------------
# Image count                     :13
# Image in process is             :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test\4dad9e43db72c2609856b02abced3755ef566383.jpg
# Image feature vector saved to   :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test/4dad9e43db72c2609856b02abced3755ef566383.npz
# -----------------------------------------------------------------------------------------
# Image count                     :14
# Image in process is             :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test\535d914ddb7bedac122a9c158012a52defbdb28e.jpg
# Image feature vector saved to   :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test/535d914ddb7bedac122a9c158012a52defbdb28e.npz
# -----------------------------------------------------------------------------------------
# Image count                     :15
# Image in process is             :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test\5b7ea4ab23dfd89d1a66ae2f256826e5c8783140.jpg
# Image feature vector saved to   :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test/5b7ea4ab23dfd89d1a66ae2f256826e5c8783140.npz
# -----------------------------------------------------------------------------------------
# Image count                     :16
# Image in process is             :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test\623b50a4f2965c9fe8c453487dd288f998b51297.jpg
# Image feature vector saved to   :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test/623b50a4f2965c9fe8c453487dd288f998b51297.npz
# -----------------------------------------------------------------------------------------
# Image count                     :17
# Image in process is             :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test\6e98e17cfef862fa83abdf351a23310d608b2b20.jpg
# Image feature vector saved to   :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test/6e98e17cfef862fa83abdf351a23310d608b2b20.npz
# -----------------------------------------------------------------------------------------
# Image count                     :18
# Image in process is             :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test\73359c7cf3b04499250039ccb456eb168afa8704.jpg
# Image feature vector saved to   :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test/73359c7cf3b04499250039ccb456eb168afa8704.npz
# -----------------------------------------------------------------------------------------
# Image count                     :19
# Image in process is             :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test\76e7932694833640c2af61030e40fd72997e7e24.jpg
# Image feature vector saved to   :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test/76e7932694833640c2af61030e40fd72997e7e24.npz
# -----------------------------------------------------------------------------------------
# Image count                     :20
# Image in process is             :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test\77e23064334f0ab47f9bd17e232bdd941b2e6c1d.jpg
# Image feature vector saved to   :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test/77e23064334f0ab47f9bd17e232bdd941b2e6c1d.npz
# -----------------------------------------------------------------------------------------
# Image count                     :21
# Image in process is             :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test\8893ea64a332765217b26680f925342a1bb4d301.jpg
# Image feature vector saved to   :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test/8893ea64a332765217b26680f925342a1bb4d301.npz
# -----------------------------------------------------------------------------------------
# Image count                     :22
# Image in process is             :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test\8e021fac89810edd9a8529814ecab1573d68b084.jpg
# Image feature vector saved to   :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test/8e021fac89810edd9a8529814ecab1573d68b084.npz
# -----------------------------------------------------------------------------------------
# Image count                     :23
# Image in process is             :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test\9769d5e06b3981d39dc1891d6da2ce8462c1c0a3.jpg
# Image feature vector saved to   :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test/9769d5e06b3981d39dc1891d6da2ce8462c1c0a3.npz
# -----------------------------------------------------------------------------------------
# Image count                     :24
# Image in process is             :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test\9b79dd411d42124016196b989bdf314838f48de2.jpg
# Image feature vector saved to   :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test/9b79dd411d42124016196b989bdf314838f48de2.npz
# -----------------------------------------------------------------------------------------
# Image count                     :25
# Image in process is             :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test\9e34b9687d45408f7c739e020bb38ae7e562e23f.jpg
# Image feature vector saved to   :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test/9e34b9687d45408f7c739e020bb38ae7e562e23f.npz
# -----------------------------------------------------------------------------------------
# Image count                     :26
# Image in process is             :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test\a14ac90619fa5b7feb187ead4d4d42ae9c59d7a7.jpg
# Image feature vector saved to   :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test/a14ac90619fa5b7feb187ead4d4d42ae9c59d7a7.npz
# -----------------------------------------------------------------------------------------
# Image count                     :27
# Image in process is             :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test\a18b4d927b103b36451835047f7a1c223908f228.jpg
# Image feature vector saved to   :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test/a18b4d927b103b36451835047f7a1c223908f228.npz
# -----------------------------------------------------------------------------------------
# Image count                     :28
# Image in process is             :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test\a940aa2eb44907bb22ad16182df5dd093b97e38c.jpg
# Image feature vector saved to   :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test/a940aa2eb44907bb22ad16182df5dd093b97e38c.npz
# -----------------------------------------------------------------------------------------
# Image count                     :29
# Image in process is             :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test\a9e393eb434fe21bd20f718c4c752f819d3acba3.jpg
# Image feature vector saved to   :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test/a9e393eb434fe21bd20f718c4c752f819d3acba3.npz
# -----------------------------------------------------------------------------------------
# Image count                     :30
# Image in process is             :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test\aeb31fa7538c4c38743afe3b5d181ffc2c504427.jpg
# Image feature vector saved to   :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test/aeb31fa7538c4c38743afe3b5d181ffc2c504427.npz
# -----------------------------------------------------------------------------------------
# Image count                     :31
# Image in process is             :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test\b2215523a1384c5583588a831b1a008e94ab2236.jpg
# Image feature vector saved to   :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test/b2215523a1384c5583588a831b1a008e94ab2236.npz
# -----------------------------------------------------------------------------------------
# Image count                     :32
# Image in process is             :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test\b3179a1855d492eb3313b59b82a1e29e8850eb92.jpg
# Image feature vector saved to   :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test/b3179a1855d492eb3313b59b82a1e29e8850eb92.npz
# -----------------------------------------------------------------------------------------
# Image count                     :33
# Image in process is             :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test\b585040bac837350fe18272763a73b9ac069aa09.jpg
# Image feature vector saved to   :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test/b585040bac837350fe18272763a73b9ac069aa09.npz
# -----------------------------------------------------------------------------------------
# Image count                     :34
# Image in process is             :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test\bb41ffeba7262ad30e7e76d7ba6cce2904c90782.jpg
# Image feature vector saved to   :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test/bb41ffeba7262ad30e7e76d7ba6cce2904c90782.npz
# -----------------------------------------------------------------------------------------
# Image count                     :35
# Image in process is             :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test\bc5abcac7a0c9ea0e6eb2be8a6b17921fed84bdf.jpg
# Image feature vector saved to   :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test/bc5abcac7a0c9ea0e6eb2be8a6b17921fed84bdf.npz
# -----------------------------------------------------------------------------------------
# Image count                     :36
# Image in process is             :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test\bfa750035da255ec6d0f71df34ac3a759e801bbf.jpg
# Image feature vector saved to   :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test/bfa750035da255ec6d0f71df34ac3a759e801bbf.npz
# -----------------------------------------------------------------------------------------
# Image count                     :37
# Image in process is             :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test\c2535cf647be0949529ddb8e78beaaf79ac0bd53.jpg
# Image feature vector saved to   :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test/c2535cf647be0949529ddb8e78beaaf79ac0bd53.npz
# -----------------------------------------------------------------------------------------
# Image count                     :38
# Image in process is             :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test\c2c0fff79e0b65a818412572e9f9364bc359fb4f.jpg
# Image feature vector saved to   :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test/c2c0fff79e0b65a818412572e9f9364bc359fb4f.npz
# -----------------------------------------------------------------------------------------
# Image count                     :39
# Image in process is             :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test\c715c4465c351f0b06415fb9a1ccbd946327fb23.jpg
# Image feature vector saved to   :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test/c715c4465c351f0b06415fb9a1ccbd946327fb23.npz
# -----------------------------------------------------------------------------------------
# Image count                     :40
# Image in process is             :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test\cba20840f15f48fae6ddaacac0721df80ae63ad8.jpg
# Image feature vector saved to   :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test/cba20840f15f48fae6ddaacac0721df80ae63ad8.npz
# -----------------------------------------------------------------------------------------
# Image count                     :41
# Image in process is             :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test\cd8320501898da6979a844f621b3a97f9f76ba0c.jpg
# Image feature vector saved to   :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test/cd8320501898da6979a844f621b3a97f9f76ba0c.npz
# -----------------------------------------------------------------------------------------
# Image count                     :42
# Image in process is             :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test\d8b30ba9b6f342c670ca0086857926cbbad4508d.jpg
# Image feature vector saved to   :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test/d8b30ba9b6f342c670ca0086857926cbbad4508d.npz
# -----------------------------------------------------------------------------------------
# Image count                     :43
# Image in process is             :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test\dc09ad64aa6f60ae863d2547652d89d2a1e4f508.jpg
# Image feature vector saved to   :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test/dc09ad64aa6f60ae863d2547652d89d2a1e4f508.npz
# -----------------------------------------------------------------------------------------
# Image count                     :44
# Image in process is             :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test\e5dddf21df0ffefc2b3b6848c701b28d42477dec.jpg
# Image feature vector saved to   :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test/e5dddf21df0ffefc2b3b6848c701b28d42477dec.npz
# -----------------------------------------------------------------------------------------
# Image count                     :45
# Image in process is             :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test\e95a8e4c52075aaa389d3d2b031c39c5570a1d99.jpg
# Image feature vector saved to   :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test/e95a8e4c52075aaa389d3d2b031c39c5570a1d99.npz
# -----------------------------------------------------------------------------------------
# Image count                     :46
# Image in process is             :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test\f170378bdd1be7568992468443d7454e1f3d24f9.jpg
# Image feature vector saved to   :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test/f170378bdd1be7568992468443d7454e1f3d24f9.npz
# -----------------------------------------------------------------------------------------
# Image count                     :47
# Image in process is             :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test\f4748df6bae208df39ac33e4d2e88ef51673666a.jpg
# Image feature vector saved to   :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test/f4748df6bae208df39ac33e4d2e88ef51673666a.npz
# -----------------------------------------------------------------------------------------
# Image count                     :48
# Image in process is             :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test\f5d05c38a69a94a93fec7e8ee357d701dc2308d9.jpg
# Image feature vector saved to   :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test/f5d05c38a69a94a93fec7e8ee357d701dc2308d9.npz
# -----------------------------------------------------------------------------------------
# Image count                     :49
# Image in process is             :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test\f7aaabd886d4f7b8736dcb4055abd94301dc846d.jpg
# Image feature vector saved to   :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test/f7aaabd886d4f7b8736dcb4055abd94301dc846d.npz
# -----------------------------------------------------------------------------------------
# Image count                     :50
# Image in process is             :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test\fd27283a5a01a7a4d4b153d4de4b38117a94f4b8.jpg
# Image feature vector saved to   :E:/3 - SPRING_2021_ADM/Lab/Lab-4/ImageSimilarityDetection/test/fd27283a5a01a7a4d4b153d4de4b38117a94f4b8.npz
# ---------------------------------
# Step.2 of 2 - Generating Feature Vectors - Completed at Fri Apr  2 12:58:03 2021
# --- 0.25 minutes passed ---------
# --- 50 images processed ---------
